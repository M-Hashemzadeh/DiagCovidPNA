# %% [markdown]
# # ***Set Parameter Network :***

# %%
total_data = 12000

n_c = 4

i_s = (150, 150, 3)

b_s = 32

l_r = 0.0003

reg = 0.0002

epoch = 100

# %% [markdown]
# # ***Import Library :***

# %%
# %matplotlib inline

import os
import math
import keras
import random
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from os import *
from tqdm import tqdm
from glob import glob
from pathlib import Path

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import *
from tensorflow.keras import regularizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.applications.densenet import preprocess_input

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Convolution2D, Input
from tensorflow.keras.layers import Flatten, MaxPooling2D, Dropout, BatchNormalization

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array

from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")
print("Tensorflow-version:", tf.__version__)
# Out:
# Tensorflow-version: 2.4.1

# %% [markdown]
# # ***Show Sample Function :***

# %%
def rand(start, end):
    rand = round(random.uniform(start, end), 1)
    return rand

# %%
def plot_images(X_data, Y_data):

    class_name = ['Covid-19', 'Normal', 'BacterialPneumonia', 'ViralPneumonia']
    samples_pre_class = n_c
    
    plt.figure(figsize=(16, 16))
    
    for cls, name in enumerate (class_name):
        idxs = np.flatnonzero(Y_data == cls)
        idxs = np.random.choice(idxs, samples_pre_class, replace = False)
        
        for i, idx in enumerate (idxs):
            plt.subplot(samples_pre_class, n_c, i*4+cls+1)
            plt.imshow(X_data[idx], interpolation= 'spline16')
            plt.axis('off')
            if i == 0:
                plt.title(class_name[cls])

# %%
def plot__images(images, title):
    nrows, ncols = 4, 4
    figsize = [16, 16]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()

# %% [markdown]
# # ***Load Train Dataset :***

# %%
img= 0
img_ary= []
covid_train_labels= []
path= Path ('C:/Dataset/Train/Covid-19').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

covid_train_images= np.array (img_ary) / 255.0

for i in img_ary:
  covid_train_labels.append (0)

print(covid_train_images.shape)
print('\n', covid_train_labels[0], len(covid_train_labels))
# Out:
# (2100, 150, 150, 3)
#
#  0 2100

# %%
img= 0
img_ary= []
normal_train_labels= []
path= Path ('C:/Dataset/Train/Normal').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

normal_train_images= np.array (img_ary) / 255.0

for i in img_ary:
  normal_train_labels.append (1)

print(normal_train_images.shape)
print('\n', normal_train_labels[0], len(normal_train_labels))
# Out:
# (2100, 150, 150, 3)
#
#  1 2100

# %%
img= 0
img_ary= []
bacterialpneumonia_train_labels= []
path= Path ('C:/Dataset/Train/Bacterial Pneumonia').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

bacterialpneumonia_train_images= np.array (img_ary) / 255.0

for i in img_ary:
  bacterialpneumonia_train_labels.append (2)

print(bacterialpneumonia_train_images.shape)
print('\n', bacterialpneumonia_train_labels[0], len(bacterialpneumonia_train_labels))
# Out:
# (2100, 150, 150, 3)
#
#  2 2100

# %%
img= 0
img_ary= []
viralpneumonia_train_labels= []
path= Path ('C:/Dataset/Train/Viral Pneumonia').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

viralpneumonia_train_images= np.array (img_ary) / 255.0

for i in img_ary:
  viralpneumonia_train_labels.append (3)

print(viralpneumonia_train_images.shape)
print('\n', viralpneumonia_train_labels[0], len(viralpneumonia_train_labels))
# Out:
# (2100, 150, 150, 3)
#
#  3 2100

# %%
covid_train_images.shape, normal_train_images.shape, bacterialpneumonia_train_images.shape, viralpneumonia_train_images.shape
# Out:
# ((2100, 150, 150, 3),
#  (2100, 150, 150, 3),
#  (2100, 150, 150, 3),
#  (2100, 150, 150, 3))

# %% [markdown]
# # ***Load Valid Dataset :***

# %%
img= 0
img_ary= []
covid_valid_labels= []
path= Path ('C:/Dataset/Valid/Covid-19').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

covid_valid_images= np.array (img_ary) / 255.0

for i in img_ary:
  covid_valid_labels.append (0)

print(covid_valid_images.shape)
print('\n', covid_valid_labels[0], len(covid_valid_labels))
# Out:
# (450, 150, 150, 3)
#
#  0 450

# %%
img= 0
img_ary= []
normal_valid_labels= []
path= Path ('C:/Dataset/Valid/Normal').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

normal_valid_images= np.array (img_ary) / 255.0

for i in img_ary:
  normal_valid_labels.append (1)

print(normal_valid_images.shape)
print('\n', normal_valid_labels[0], len(normal_valid_labels))
# Out:
# (450, 150, 150, 3)
#
#  1 450

# %%
img= 0
img_ary= []
bacterialpneumonia_valid_labels= []
path= Path ('C:/Dataset/Valid/Bacterial Pneumonia').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

bacterialpneumonia_valid_images= np.array (img_ary) / 255.0

for i in img_ary:
  bacterialpneumonia_valid_labels.append (2)

print(bacterialpneumonia_valid_images.shape)
print('\n', bacterialpneumonia_valid_labels[0], len(bacterialpneumonia_valid_labels))
# Out:
# (450, 150, 150, 3)
#
#  2 450

# %%
img= 0
img_ary= []
viralpneumonia_valid_labels= []
path= Path ('C:/Dataset/Valid/Viral Pneumonia').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

viralpneumonia_valid_images= np.array (img_ary) / 255.0

for i in img_ary:
  viralpneumonia_valid_labels.append (3)

print(viralpneumonia_valid_images.shape)
print('\n', viralpneumonia_valid_labels[0], len(viralpneumonia_valid_labels))
# Out:
# (450, 150, 150, 3)
#
#  3 450

# %%
covid_valid_images.shape, normal_valid_images.shape, bacterialpneumonia_valid_images.shape, viralpneumonia_valid_images.shape
# Out:
# ((450, 150, 150, 3),
#  (450, 150, 150, 3),
#  (450, 150, 150, 3),
#  (450, 150, 150, 3))

# %% [markdown]
# # ***Load Test Dataset :***

# %%
img= 0
img_ary= []
covid_test_labels= []
path= Path ('C:/Dataset/Test/Covid-19').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

covid_test_images= np.array (img_ary) / 255.0

for i in img_ary:
  covid_test_labels.append (0)

print(covid_test_images.shape)
print('\n', covid_test_labels[0], len(covid_test_labels))
# Out:
# (450, 150, 150, 3)
#
#  0 450

# %%
img= 0
img_ary= []
normal_test_labels= []
path= Path ('C:/Dataset/Test/Normal').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

normal_test_images= np.array (img_ary) / 255.0

for i in img_ary:
  normal_test_labels.append (1)

print(normal_test_images.shape)
print('\n', normal_test_labels[0], len(normal_test_labels))
# Out:
# (450, 150, 150, 3)
#
#  1 450

# %%
img= 0
img_ary= []
bacterialpneumonia_test_labels= []
path= Path ('C:/Dataset/Test/Bacterial Pneumonia').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

bacterialpneumonia_test_images= np.array (img_ary) / 255.0

for i in img_ary:
  bacterialpneumonia_test_labels.append (2)

print(bacterialpneumonia_test_images.shape)
print('\n', bacterialpneumonia_test_labels[0], len(bacterialpneumonia_test_labels))
# Out:
# (450, 150, 150, 3)
#
#  2 450

# %%
img= 0
img_ary= []
viralpneumonia_test_labels= []
path= Path ('C:/Dataset/Test/Viral Pneumonia').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

viralpneumonia_test_images= np.array (img_ary) / 255.0

for i in img_ary:
  viralpneumonia_test_labels.append (3)

print(viralpneumonia_test_images.shape)
print('\n', viralpneumonia_test_labels[0], len(viralpneumonia_test_labels))
# Out:
# (450, 150, 150, 3)
#
#  3 450

# %%
covid_test_images.shape, normal_test_images.shape, bacterialpneumonia_test_images.shape, viralpneumonia_test_images.shape
# Out:
# ((450, 150, 150, 3),
#  (450, 150, 150, 3),
#  (450, 150, 150, 3),
#  (450, 150, 150, 3))

# %% [markdown]
# # ***Data Visulisation :***

# %%
c_l= np.zeros(len (covid_train_images))
n_l= np.ones (len (normal_train_images))
b_l= np.full (len (bacterialpneumonia_train_images), 2, dtype= int)
v_l= np.full (len (viralpneumonia_train_images), 3, dtype= int)

X_data= np.concatenate ((covid_train_images, normal_train_images, bacterialpneumonia_train_images, viralpneumonia_train_images), axis=0)
Y_data= np.concatenate ((c_l, n_l, b_l, v_l), axis=0)

plot_images(X_data, Y_data)

# %% [markdown]
# # ***Prepare Data :***

# %%
X_train = np.concatenate ((covid_train_images, normal_train_images, bacterialpneumonia_train_images, viralpneumonia_train_images), axis=0)

Y_train = np.concatenate ((covid_train_labels, normal_train_labels, bacterialpneumonia_train_labels, viralpneumonia_train_labels), axis=0)

# %%
X_valid = np.concatenate ((covid_valid_images, normal_valid_images, bacterialpneumonia_valid_images, viralpneumonia_valid_images), axis=0)

Y_valid = np.concatenate ((covid_valid_labels, normal_valid_labels, bacterialpneumonia_valid_labels, viralpneumonia_valid_labels), axis=0)

# %%
X_test = np.concatenate ((covid_test_images, normal_test_images, bacterialpneumonia_test_images, viralpneumonia_test_images), axis=0)

Y_test = np.concatenate ((covid_test_labels, normal_test_labels, bacterialpneumonia_test_labels, viralpneumonia_test_labels), axis=0)

# %% [markdown]
# # ***Categorical Lable Dataset :***

# %%
Y_train = to_categorical (
                          Y_train, num_classes = n_c
                         )

Y_valid = to_categorical (
                          Y_valid, num_classes = n_c
                         )

Y_test = to_categorical (
                         Y_test, num_classes = n_c
                        )

# %% [markdown]
# # ***Adjusted Contrast :***

# %%
C_train = []

for i in X_train:
    contrast = tf.image.adjust_contrast(i, rand(1.0, 1.5))
    C_train.append(contrast.numpy()) 
    
C_train = np.array(C_train, dtype=np.float32)

plot__images(C_train, 'Adjusted Contrast')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
train_datagen = ImageDataGenerator()

valid_datagen = ImageDataGenerator()

# %% [markdown]
# # ***Detail Dataset :***

# %%
print('Number Total data : ' ,total_data)

print('\nNumber Train data : ' ,len(X_train))

print('\nNumber Valid data : ' ,len(X_valid))

print('\nNumber Test data  : ' ,len(X_test))
# Out:
# Number Total data :  12000
#
# Number Train data :  8400
#
# Number Valid data :  1800
#
# Number Test data  :  1800

# %% [markdown]
# # ***Model :***

# %%
Model_X = Xception (
                    weights = 'imagenet',
                    include_top = False, 
                    input_shape = i_s
                   ) 

out = Model_X.output

out = GlobalAveragePooling2D()(out)
out = BatchNormalization()(out)
out = Dropout(0.5)(out)

out = Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(reg))(out) 
out = BatchNormalization()(out)
out = Dropout(0.5)(out)

out = Dense(512, activation='relu', kernel_regularizer=regularizers.l2(reg))(out) 
out = BatchNormalization()(out)
out = Dropout(0.5)(out)

out = Dense(256, activation='relu', kernel_regularizer=regularizers.l2(reg))(out) 
out = BatchNormalization()(out)
out = Dropout(0.5)(out)

out = Dense(n_c, activation = 'softmax')(out)

# %%
model = Model (inputs = Model_X.input, outputs = out)

for layer in Model_X.layers:
    layer.trainable = True

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 74, 74, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 74, 74, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 74, 74, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 72, 72, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 72, 72, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 72, 72, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 72, 72, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 72, 72, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 72, 72, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 72, 72, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 72, 72, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 36, 36, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 36, 36, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 36, 36, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 36, 36, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 36, 36, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 36, 36, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 36, 36, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 36, 36, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 36, 36, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 36, 36, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 18, 18, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 18, 18, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 18, 18, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 18, 18, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 18, 18, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 18, 18, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 18, 18, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 18, 18, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 18, 18, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 18, 18, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 9, 9, 728)    186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 9, 9, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 9, 9, 728)    2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 9, 9, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 9, 9, 728)    0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 9, 9, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 9, 9, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 9, 9, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 9, 9, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 9, 9, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 9, 9, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 9, 9, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 9, 9, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 9, 9, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 9, 9, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 9, 9, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 9, 9, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 9, 9, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 9, 9, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 9, 9, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 9, 9, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 9, 9, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 9, 9, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 9, 9, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 9, 9, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 9, 9, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 9, 9, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 9, 9, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 9, 9, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 9, 9, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 9, 9, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 9, 9, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 9, 9, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 9, 9, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 9, 9, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 9, 9, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 9, 9, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 9, 9, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 9, 9, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 9, 9, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 9, 9, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 9, 9, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 9, 9, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 9, 9, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 9, 9, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 9, 9, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 9, 9, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 9, 9, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 9, 9, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 9, 9, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 9, 9, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 9, 9, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 9, 9, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 9, 9, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 9, 9, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 9, 9, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 9, 9, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 9, 9, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 9, 9, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 9, 9, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 9, 9, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 9, 9, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 9, 9, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 9, 9, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 9, 9, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 9, 9, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 9, 9, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 9, 9, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 9, 9, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 9, 9, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 9, 9, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 9, 9, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 9, 9, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 9, 9, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 9, 9, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 9, 9, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 9, 9, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 9, 9, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 9, 9, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 9, 9, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 9, 9, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 9, 9, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 9, 9, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 9, 9, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 9, 9, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 9, 9, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 9, 9, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 9, 9, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 9, 9, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 9, 9, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 5, 5, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 5, 5, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 5, 5, 1024)   4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 5, 5, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 5, 5, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 5, 5, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 5, 5, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 5, 5, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 5, 5, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 5, 5, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 2048)         8192        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         2098176     dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 1024)         4096        dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          524800      dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 512)          2048        dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          131328      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256)          1024        dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 256)          0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            1028        dropout_3[0][0]
# ==================================================================================================
# Total params: 23,632,172
# Trainable params: 23,569,964
# Non-trainable params: 62,208
# __________________________________________________________________________________________________

# %% [markdown]
# # ***Set Compile Parameter :***

# %%
adam = tf.keras.optimizers.Adam (learning_rate = l_r)

model.compile (
               loss = 'categorical_crossentropy', 
               optimizer = adam, 
               metrics = ['accuracy']
              )

# %% [markdown]
# # ***Checkpoint :***

# %%
checkpoint_path = 'Checkpoints/'

checkpoint = ModelCheckpoint(
                             filepath = checkpoint_path,
                             save_freq = 'epoch',
                             save_weights_only = False,
                             verbose = 2
                            )

# %% [markdown]
# # ***fit Model :***

# %%
history= model.fit (
                    train_datagen.flow(C_train, Y_train, batch_size = b_s),
  validation_data = valid_datagen.flow(X_valid, Y_valid, batch_size = b_s),

                    validation_steps=len(X_valid) // b_s,
                    steps_per_epoch =len(X_train) // b_s,
        
                    epochs = epoch,
                    callbacks = [checkpoint]
                   )
# Out:
# Epoch 1/100
# 262/262 [==============================] - 2799s 11s/step - loss: 1.6175 - accuracy: 0.5956 - val_loss: 1.1815 - val_accuracy: 0.6914
#
# Epoch 00001: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 2/100
# 262/262 [==============================] - 2735s 10s/step - loss: 0.9995 - accuracy: 0.8033 - val_loss: 0.8655 - val_accuracy: 0.8426
#
# Epoch 00002: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 3/100
# 262/262 [==============================] - 2685s 10s/step - loss: 0.8293 - accuracy: 0.8649 - val_loss: 0.8140 - val_accuracy: 0.8677
#
# Epoch 00003: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 4/100
# 262/262 [==============================] - 2593s 10s/step - loss: 0.7052 - accuracy: 0.9094 - val_loss: 0.7826 - val_accuracy: 0.8761
#
# Epoch 00004: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 5/100
# 262/262 [==============================] - 2607s 10s/step - loss: 0.6304 - accuracy: 0.9415 - val_loss: 0.7894 - val_accuracy: 0.8683
#
# Epoch 00005: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 6/100
# 262/262 [==============================] - 2588s 10s/step - loss: 0.5935 - accuracy: 0.9544 - val_loss: 0.7497 - val_accuracy: 0.8912
#
# Epoch 00006: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 7/100
# 262/262 [==============================] - 2588s 10s/step - loss: 0.5702 - accuracy: 0.9611 - val_loss: 0.7786 - val_accuracy: 0.8945
#
# Epoch 00007: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 8/100
# 262/262 [==============================] - 2634s 10s/step - loss: 0.5435 - accuracy: 0.9664 - val_loss: 0.7699 - val_accuracy: 0.8934
#
# Epoch 00008: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 9/100
# 262/262 [==============================] - 2600s 10s/step - loss: 0.5153 - accuracy: 0.9727 - val_loss: 0.8418 - val_accuracy: 0.8672
#
# Epoch 00009: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 10/100
# 262/262 [==============================] - 2599s 10s/step - loss: 0.5112 - accuracy: 0.9713 - val_loss: 0.7594 - val_accuracy: 0.8890
#
# Epoch 00010: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 11/100
# 262/262 [==============================] - 2603s 10s/step - loss: 0.4714 - accuracy: 0.9762 - val_loss: 0.7366 - val_accuracy: 0.8867
#
# Epoch 00011: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 12/100
# 262/262 [==============================] - 2605s 10s/step - loss: 0.4590 - accuracy: 0.9780 - val_loss: 0.6454 - val_accuracy: 0.9141
#
# Epoch 00012: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 13/100
# 262/262 [==============================] - 2596s 10s/step - loss: 0.4244 - accuracy: 0.9826 - val_loss: 0.6638 - val_accuracy: 0.9118
#
# Epoch 00013: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 14/100
# 262/262 [==============================] - 2614s 10s/step - loss: 0.4117 - accuracy: 0.9828 - val_loss: 0.6570 - val_accuracy: 0.9057
#
# Epoch 00014: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 15/100
# 262/262 [==============================] - 2624s 10s/step - loss: 0.4151 - accuracy: 0.9748 - val_loss: 0.6175 - val_accuracy: 0.9191
#
# Epoch 00015: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 16/100
# 262/262 [==============================] - 2592s 10s/step - loss: 0.3670 - accuracy: 0.9854 - val_loss: 0.6506 - val_accuracy: 0.9102
#
# Epoch 00016: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 17/100
# 262/262 [==============================] - 2598s 10s/step - loss: 0.3470 - accuracy: 0.9846 - val_loss: 0.5895 - val_accuracy: 0.9090
#
# Epoch 00017: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 18/100
# 262/262 [==============================] - 2606s 10s/step - loss: 0.3460 - accuracy: 0.9797 - val_loss: 0.6331 - val_accuracy: 0.9018
#
# Epoch 00018: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 19/100
# 262/262 [==============================] - 2598s 10s/step - loss: 0.3428 - accuracy: 0.9735 - val_loss: 0.6562 - val_accuracy: 0.8956
#
# Epoch 00019: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 20/100
# 262/262 [==============================] - 2618s 10s/step - loss: 0.2726 - accuracy: 0.9904 - val_loss: 0.8376 - val_accuracy: 0.8549
#
# Epoch 00020: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 21/100
# 262/262 [==============================] - 2614s 10s/step - loss: 0.2803 - accuracy: 0.9834 - val_loss: 0.5594 - val_accuracy: 0.9074
#
# Epoch 00021: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 22/100
# 262/262 [==============================] - 2607s 10s/step - loss: 0.2929 - accuracy: 0.9776 - val_loss: 0.5066 - val_accuracy: 0.9085
#
# Epoch 00022: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 23/100
# 262/262 [==============================] - 2599s 10s/step - loss: 0.2167 - accuracy: 0.9915 - val_loss: 0.6721 - val_accuracy: 0.8683
#
# Epoch 00023: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 24/100
# 262/262 [==============================] - 2604s 10s/step - loss: 0.2121 - accuracy: 0.9870 - val_loss: 0.5474 - val_accuracy: 0.8817
#
# Epoch 00024: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 25/100
# 262/262 [==============================] - 2630s 10s/step - loss: 0.1857 - accuracy: 0.9910 - val_loss: 0.4227 - val_accuracy: 0.9174
#
# Epoch 00025: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 26/100
# 262/262 [==============================] - 2609s 10s/step - loss: 0.1697 - accuracy: 0.9900 - val_loss: 0.4395 - val_accuracy: 0.9051
#
# Epoch 00026: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 27/100
# 262/262 [==============================] - 2612s 10s/step - loss: 0.1521 - accuracy: 0.9904 - val_loss: 0.5178 - val_accuracy: 0.9085
#
# Epoch 00027: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 28/100
# 262/262 [==============================] - 2606s 10s/step - loss: 0.1556 - accuracy: 0.9858 - val_loss: 0.5814 - val_accuracy: 0.8767
#
# Epoch 00028: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 29/100
# 262/262 [==============================] - 2614s 10s/step - loss: 0.1342 - accuracy: 0.9897 - val_loss: 0.3459 - val_accuracy: 0.9213
#
# Epoch 00029: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 30/100
# 262/262 [==============================] - 2617s 10s/step - loss: 0.1236 - accuracy: 0.9895 - val_loss: 0.4382 - val_accuracy: 0.9085
#
# Epoch 00030: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 31/100
# 262/262 [==============================] - 2620s 10s/step - loss: 0.1072 - accuracy: 0.9948 - val_loss: 0.4052 - val_accuracy: 0.9219
#
# Epoch 00031: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 32/100
# 262/262 [==============================] - 2610s 10s/step - loss: 0.1178 - accuracy: 0.9885 - val_loss: 0.3643 - val_accuracy: 0.9174
#
# Epoch 00032: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 33/100
# 262/262 [==============================] - 2618s 10s/step - loss: 0.1032 - accuracy: 0.9906 - val_loss: 0.4570 - val_accuracy: 0.9129
#
# Epoch 00033: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 34/100
# 262/262 [==============================] - 2607s 10s/step - loss: 0.0820 - accuracy: 0.9962 - val_loss: 0.3741 - val_accuracy: 0.9235
#
# Epoch 00034: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 35/100
# 262/262 [==============================] - 2615s 10s/step - loss: 0.0851 - accuracy: 0.9940 - val_loss: 0.3939 - val_accuracy: 0.9174
#
# Epoch 00035: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 36/100
# 262/262 [==============================] - 2615s 10s/step - loss: 0.0736 - accuracy: 0.9942 - val_loss: 0.4596 - val_accuracy: 0.8951
#
# Epoch 00036: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 37/100
# 262/262 [==============================] - 2603s 10s/step - loss: 0.1078 - accuracy: 0.9871 - val_loss: 0.3977 - val_accuracy: 0.9107
#
# Epoch 00037: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 38/100
# 262/262 [==============================] - 2607s 10s/step - loss: 0.0751 - accuracy: 0.9955 - val_loss: 0.3790 - val_accuracy: 0.9263
#
# Epoch 00038: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 39/100
# 262/262 [==============================] - 2583s 10s/step - loss: 0.0593 - accuracy: 0.9973 - val_loss: 0.4017 - val_accuracy: 0.9068
#
# Epoch 00039: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 40/100
# 262/262 [==============================] - 2582s 10s/step - loss: 0.0584 - accuracy: 0.9968 - val_loss: 0.3509 - val_accuracy: 0.9302
#
# Epoch 00040: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 41/100
# 262/262 [==============================] - 2616s 10s/step - loss: 0.0970 - accuracy: 0.9836 - val_loss: 0.3756 - val_accuracy: 0.9085
#
# Epoch 00041: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 42/100
# 262/262 [==============================] - 2642s 10s/step - loss: 0.0793 - accuracy: 0.9926 - val_loss: 0.3064 - val_accuracy: 0.9280
#
# Epoch 00042: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 43/100
# 262/262 [==============================] - 2637s 10s/step - loss: 0.0553 - accuracy: 0.9967 - val_loss: 0.4175 - val_accuracy: 0.9202
#
# Epoch 00043: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 44/100
# 262/262 [==============================] - 2604s 10s/step - loss: 0.0554 - accuracy: 0.9949 - val_loss: 0.4235 - val_accuracy: 0.9141
#
# Epoch 00044: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 45/100
# 262/262 [==============================] - 2611s 10s/step - loss: 0.0769 - accuracy: 0.9890 - val_loss: 0.3993 - val_accuracy: 0.9241
#
# Epoch 00045: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 46/100
# 262/262 [==============================] - 2593s 10s/step - loss: 0.0596 - accuracy: 0.9942 - val_loss: 0.4048 - val_accuracy: 0.9068
#
# Epoch 00046: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 47/100
# 262/262 [==============================] - 2581s 10s/step - loss: 0.0630 - accuracy: 0.9944 - val_loss: 0.4786 - val_accuracy: 0.8856
#
# Epoch 00047: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 48/100
# 262/262 [==============================] - 2595s 10s/step - loss: 0.0620 - accuracy: 0.9929 - val_loss: 0.4080 - val_accuracy: 0.9141
#
# Epoch 00048: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 49/100
# 262/262 [==============================] - 2606s 10s/step - loss: 0.0769 - accuracy: 0.9889 - val_loss: 0.3895 - val_accuracy: 0.9107
#
# Epoch 00049: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 50/100
# 262/262 [==============================] - 2610s 10s/step - loss: 0.0673 - accuracy: 0.9929 - val_loss: 0.3494 - val_accuracy: 0.9291
#
# Epoch 00050: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 51/100
# 262/262 [==============================] - 2603s 10s/step - loss: 0.0504 - accuracy: 0.9975 - val_loss: 0.5034 - val_accuracy: 0.9023
#
# Epoch 00051: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 52/100
# 262/262 [==============================] - 2612s 10s/step - loss: 0.0469 - accuracy: 0.9970 - val_loss: 0.4299 - val_accuracy: 0.9102
#
# Epoch 00052: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 53/100
# 262/262 [==============================] - 2611s 10s/step - loss: 0.0690 - accuracy: 0.9910 - val_loss: 0.4683 - val_accuracy: 0.9096
#
# Epoch 00053: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 54/100
# 262/262 [==============================] - 2610s 10s/step - loss: 0.0474 - accuracy: 0.9961 - val_loss: 0.4642 - val_accuracy: 0.9001
#
# Epoch 00054: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 55/100
# 262/262 [==============================] - 2614s 10s/step - loss: 0.0613 - accuracy: 0.9940 - val_loss: 0.3790 - val_accuracy: 0.9185
#
# Epoch 00055: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 56/100
# 262/262 [==============================] - 2608s 10s/step - loss: 0.0332 - accuracy: 0.9987 - val_loss: 0.3225 - val_accuracy: 0.9224
#
# Epoch 00056: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 57/100
# 262/262 [==============================] - 2619s 10s/step - loss: 0.0292 - accuracy: 0.9994 - val_loss: 0.3477 - val_accuracy: 0.9118
#
# Epoch 00057: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 58/100
# 262/262 [==============================] - 2588s 10s/step - loss: 0.0452 - accuracy: 0.9944 - val_loss: 0.4005 - val_accuracy: 0.9107
#
# Epoch 00058: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 59/100
# 262/262 [==============================] - 2593s 10s/step - loss: 0.0320 - accuracy: 0.9978 - val_loss: 0.5670 - val_accuracy: 0.8728
#
# Epoch 00059: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 60/100
# 262/262 [==============================] - 2590s 10s/step - loss: 0.0763 - accuracy: 0.9898 - val_loss: 0.4321 - val_accuracy: 0.9146
#
# Epoch 00060: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 61/100
# 262/262 [==============================] - 2616s 10s/step - loss: 0.0601 - accuracy: 0.9939 - val_loss: 0.3912 - val_accuracy: 0.9129
#
# Epoch 00061: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 62/100
# 262/262 [==============================] - 2591s 10s/step - loss: 0.0438 - accuracy: 0.9968 - val_loss: 0.3893 - val_accuracy: 0.9085
#
# Epoch 00062: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 63/100
# 262/262 [==============================] - 2594s 10s/step - loss: 0.0506 - accuracy: 0.9932 - val_loss: 0.3527 - val_accuracy: 0.9224
#
# Epoch 00063: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 64/100
# 262/262 [==============================] - 2591s 10s/step - loss: 0.0419 - accuracy: 0.9962 - val_loss: 0.5004 - val_accuracy: 0.8940
#
# Epoch 00064: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 65/100
# 262/262 [==============================] - 2588s 10s/step - loss: 0.0721 - accuracy: 0.9900 - val_loss: 0.3640 - val_accuracy: 0.9090
#
# Epoch 00065: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 66/100
# 262/262 [==============================] - 2588s 10s/step - loss: 0.0590 - accuracy: 0.9945 - val_loss: 0.4520 - val_accuracy: 0.9007
#
# Epoch 00066: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 67/100
# 262/262 [==============================] - 2582s 10s/step - loss: 0.0419 - accuracy: 0.9972 - val_loss: 0.6684 - val_accuracy: 0.8956
#
# Epoch 00067: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 68/100
# 262/262 [==============================] - 2594s 10s/step - loss: 0.0703 - accuracy: 0.9904 - val_loss: 0.3647 - val_accuracy: 0.9208
#
# Epoch 00068: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 69/100
# 262/262 [==============================] - 2594s 10s/step - loss: 0.0313 - accuracy: 0.9987 - val_loss: 0.6608 - val_accuracy: 0.8717
#
# Epoch 00069: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 70/100
# 262/262 [==============================] - 2595s 10s/step - loss: 0.1315 - accuracy: 0.9804 - val_loss: 0.3736 - val_accuracy: 0.9196
#
# Epoch 00070: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 71/100
# 262/262 [==============================] - 2582s 10s/step - loss: 0.0459 - accuracy: 0.9968 - val_loss: 0.4181 - val_accuracy: 0.9102
#
# Epoch 00071: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 72/100
# 262/262 [==============================] - 2587s 10s/step - loss: 0.0565 - accuracy: 0.9934 - val_loss: 0.4306 - val_accuracy: 0.9180
#
# Epoch 00072: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 73/100
# 262/262 [==============================] - 2595s 10s/step - loss: 0.0440 - accuracy: 0.9968 - val_loss: 0.3960 - val_accuracy: 0.9252
#
# Epoch 00073: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 74/100
# 262/262 [==============================] - 2578s 10s/step - loss: 0.0315 - accuracy: 0.9983 - val_loss: 0.5640 - val_accuracy: 0.9074
#
# Epoch 00074: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 75/100
# 262/262 [==============================] - 2595s 10s/step - loss: 0.0434 - accuracy: 0.9955 - val_loss: 0.5298 - val_accuracy: 0.8968
#
# Epoch 00075: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 76/100
# 262/262 [==============================] - 2603s 10s/step - loss: 0.0434 - accuracy: 0.9968 - val_loss: 0.4093 - val_accuracy: 0.9224
#
# Epoch 00076: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 77/100
# 262/262 [==============================] - 2591s 10s/step - loss: 0.0676 - accuracy: 0.9921 - val_loss: 0.4742 - val_accuracy: 0.9057
#
# Epoch 00077: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 78/100
# 262/262 [==============================] - 2594s 10s/step - loss: 0.0469 - accuracy: 0.9969 - val_loss: 0.5762 - val_accuracy: 0.8845
#
# Epoch 00078: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 79/100
# 262/262 [==============================] - 2597s 10s/step - loss: 0.0613 - accuracy: 0.9911 - val_loss: 0.4309 - val_accuracy: 0.9085
#
# Epoch 00079: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 80/100
# 262/262 [==============================] - 2604s 10s/step - loss: 0.0399 - accuracy: 0.9972 - val_loss: 0.3813 - val_accuracy: 0.9169
#
# Epoch 00080: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 81/100
# 262/262 [==============================] - 2629s 10s/step - loss: 0.0361 - accuracy: 0.9976 - val_loss: 0.4528 - val_accuracy: 0.9157
#
# Epoch 00081: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 82/100
# 262/262 [==============================] - 2628s 10s/step - loss: 0.0331 - accuracy: 0.9969 - val_loss: 0.4845 - val_accuracy: 0.9102
#
# Epoch 00082: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 83/100
# 262/262 [==============================] - 2623s 10s/step - loss: 0.0471 - accuracy: 0.9943 - val_loss: 0.4494 - val_accuracy: 0.9129
#
# Epoch 00083: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 84/100
# 262/262 [==============================] - 2655s 10s/step - loss: 0.0314 - accuracy: 0.9996 - val_loss: 0.5913 - val_accuracy: 0.9029
#
# Epoch 00084: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 85/100
# 262/262 [==============================] - 2626s 10s/step - loss: 0.0484 - accuracy: 0.9959 - val_loss: 0.4061 - val_accuracy: 0.9169
#
# Epoch 00085: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 86/100
# 262/262 [==============================] - 2620s 10s/step - loss: 0.0501 - accuracy: 0.9955 - val_loss: 0.4060 - val_accuracy: 0.9118
#
# Epoch 00086: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 87/100
# 262/262 [==============================] - 2601s 10s/step - loss: 0.0618 - accuracy: 0.9961 - val_loss: 0.3849 - val_accuracy: 0.9202
#
# Epoch 00087: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 88/100
# 262/262 [==============================] - 2601s 10s/step - loss: 0.0322 - accuracy: 0.9986 - val_loss: 0.3690 - val_accuracy: 0.9196
#
# Epoch 00088: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 89/100
# 262/262 [==============================] - 2600s 10s/step - loss: 0.0309 - accuracy: 0.9978 - val_loss: 0.3986 - val_accuracy: 0.9180
#
# Epoch 00089: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 90/100
# 262/262 [==============================] - 2589s 10s/step - loss: 0.0712 - accuracy: 0.9885 - val_loss: 0.3467 - val_accuracy: 0.9202
#
# Epoch 00090: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 91/100
# 262/262 [==============================] - 2607s 10s/step - loss: 0.0426 - accuracy: 0.9960 - val_loss: 0.3879 - val_accuracy: 0.9219
#
# Epoch 00091: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 92/100
# 262/262 [==============================] - 2588s 10s/step - loss: 0.0453 - accuracy: 0.9958 - val_loss: 0.4243 - val_accuracy: 0.9185
#
# Epoch 00092: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 93/100
# 262/262 [==============================] - 2601s 10s/step - loss: 0.0374 - accuracy: 0.9967 - val_loss: 0.4215 - val_accuracy: 0.9141
#
# Epoch 00093: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 94/100
# 262/262 [==============================] - 2619s 10s/step - loss: 0.0300 - accuracy: 0.9978 - val_loss: 0.6499 - val_accuracy: 0.8761
#
# Epoch 00094: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 95/100
# 262/262 [==============================] - 2598s 10s/step - loss: 0.0684 - accuracy: 0.9887 - val_loss: 0.3712 - val_accuracy: 0.9185
#
# Epoch 00095: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 96/100
# 262/262 [==============================] - 2607s 10s/step - loss: 0.0413 - accuracy: 0.9966 - val_loss: 0.3712 - val_accuracy: 0.9208
#
# Epoch 00096: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 97/100
# 262/262 [==============================] - 2606s 10s/step - loss: 0.0262 - accuracy: 0.9993 - val_loss: 0.4856 - val_accuracy: 0.9090
#
# Epoch 00097: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 98/100
# 262/262 [==============================] - 2653s 10s/step - loss: 0.0433 - accuracy: 0.9934 - val_loss: 0.4392 - val_accuracy: 0.8951
#
# Epoch 00098: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 99/100
# 262/262 [==============================] - 2716s 10s/step - loss: 0.0434 - accuracy: 0.9958 - val_loss: 0.3590 - val_accuracy: 0.9291
#
# Epoch 00099: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# Epoch 100/100
# 262/262 [==============================] - 2711s 10s/step - loss: 0.0496 - accuracy: 0.9958 - val_loss: 0.4353 - val_accuracy: 0.9169
#
# Epoch 00100: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets

# %% [markdown]
# # ***Save Model :***

# %%
model.save('Model.h5')

# %% [markdown]
# # ***Evaluate Model :***

# %%
train_score = model.evaluate(X_train, Y_train, verbose=0)
valid_score = model.evaluate(X_valid, Y_valid, verbose=0)
test_score  = model.evaluate(X_test , Y_test , verbose=0)

print(f'Train loss: {train_score[0]} \n Train accuracy: {train_score[1]}')
print(f'Valid loss: {valid_score[0]} \n Valid accuracy: {valid_score[1]}')
print(f'Test  loss: {test_score[0]}  \n Test accuracy : {test_score[1]}')
# Out:
# Train loss: 0.04219406843185425
#  Train accuracy: 0.9975000023841858
# Valid loss: 0.4334633946418762
#  Valid accuracy: 0.9172222018241882
# Test  loss: 0.3385138213634491
#  Test accuracy : 0.9316666722297668

# %% [markdown]
# # ***Results Evaluate Model :***

# %%
Y_pred = model.predict(X_test)

Y_pred = np.argmax (Y_pred, axis=1)
Y_true = np.argmax (Y_test, axis=1)

# %%
target = ['Covid-19', 'Normal', 'BacterialPneumonia', 'ViralPneumonia']
print(classification_report(Y_true, Y_pred, target_names = target))
# Out:
#                     precision    recall  f1-score   support
#
#           Covid-19       0.99      1.00      1.00       450
#             Normal       0.99      0.96      0.97       450
# BacterialPneumonia       0.91      0.84      0.87       450
#     ViralPneumonia       0.84      0.93      0.89       450
#
#           accuracy                           0.93      1800
#          macro avg       0.93      0.93      0.93      1800
#       weighted avg       0.93      0.93      0.93      1800

# %% [markdown]
# # ***Confusion Matrix :***

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
        
    plt.tight_layout()
    plt.ylabel('True label', fontstyle = 'italic', color='blue', fontsize = 'x-large')
    plt.xlabel('Predicted label', fontstyle = 'italic', color='blue', fontsize = 'xx-large')

cnf_matrix = confusion_matrix(Y_true, Y_pred)
np.set_printoptions(precision=2)

fig = plt.figure(figsize=(8,8))
fig.patch.set_facecolor('gray')
plot_confusion_matrix(cnf_matrix, classes = target, title='Confusion matrix, without normalization\n\n')

fig = plt.figure(figsize=(8,8))
fig.patch.set_facecolor('gray')
plot_confusion_matrix(cnf_matrix, classes = target, normalize = True, title = 'Normalized confusion matrix\n\n')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[449   0   1   0]
#  [  2 432   9   7]
#  [  0   3 377  70]
#  [  1   2  28 419]]
# Normalized confusion matrix
# [[1.   0.   0.   0.  ]
#  [0.   0.96 0.02 0.02]
#  [0.   0.01 0.84 0.16]
#  [0.   0.   0.06 0.93]]

# %% [markdown]
# # ***Plot Accuracy :***

# %%
plt.figure(figsize=(17,10))
plt.style.use('dark_background')

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])

plt.show()

# %% [markdown]
# # ***Plot Loss :***

# %%
plt.figure(figsize=(17,10))
plt.style.use('dark_background')

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])

plt.show()
