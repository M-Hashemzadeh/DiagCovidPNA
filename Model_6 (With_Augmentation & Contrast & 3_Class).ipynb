# %% [markdown]
# # ***Set Parameter Network :***

# %%
total_data = 9000

n_c = 3

i_s = (150, 150, 3)

b_s = 32

l_r = 0.0003

reg = 0.0002

epoch = 100

# %% [markdown]
# # ***Import Library :***

# %%
# %matplotlib inline

import os
import math
import keras
import random
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from os import *
from tqdm import tqdm
from glob import glob
from pathlib import Path

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import *
from tensorflow.keras import regularizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.applications.densenet import preprocess_input

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Convolution2D, Input
from tensorflow.keras.layers import Flatten, MaxPooling2D, Dropout, BatchNormalization

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array

from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")
print("Tensorflow-version:", tf.__version__)
# Out:
# Tensorflow-version: 2.3.0

# %% [markdown]
# # ***Show Sample Function :***

# %%
def rand(start, end):
    rand = round(random.uniform(start, end), 1)
    return rand

# %%
def plot_images(X_data, Y_data):

    class_name = ['Covid-19', 'Normal', 'BacterialPneumonia']
    samples_pre_class = n_c
    
    plt.figure(figsize=(16, 16))
    
    for cls, name in enumerate (class_name):
        idxs = np.flatnonzero(Y_data == cls)
        idxs = np.random.choice(idxs, samples_pre_class, replace = False)
        
        for i, idx in enumerate (idxs):
            plt.subplot(samples_pre_class, n_c, i*3+cls+1)
            plt.imshow(X_data[idx], interpolation= 'spline16')
            plt.axis('off')
            if i == 0:
                plt.title(class_name[cls])

# %%
def plot__images(images, title):
    nrows, ncols = 3, 3
    figsize = [16, 16]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()

# %% [markdown]
# # ***Load Train Dataset :***

# %%
img= 0
img_ary= []
covid_train_labels= []
path= Path ('C:/Dataset/Train/Covid-19').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

covid_train_images= np.array (img_ary) / 255.0

for i in img_ary:
  covid_train_labels.append (0)

print(covid_train_images.shape)
print('\n', covid_train_labels[0], len(covid_train_labels))
# Out:
# (2100, 150, 150, 3)
#
#  0 2100

# %%
img= 0
img_ary= []
normal_train_labels= []
path= Path ('C:/Dataset/Train/Normal').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

normal_train_images= np.array (img_ary) / 255.0

for i in img_ary:
  normal_train_labels.append (1)

print(normal_train_images.shape)
print('\n', normal_train_labels[0], len(normal_train_labels))
# Out:
# (2100, 150, 150, 3)
#
#  1 2100

# %%
img= 0
img_ary= []
bacterialpneumonia_train_labels= []
path= Path ('C:/Dataset/Train/Bacterial Pneumonia').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

bacterialpneumonia_train_images= np.array (img_ary) / 255.0

for i in img_ary:
  bacterialpneumonia_train_labels.append (2)

print(bacterialpneumonia_train_images.shape)
print('\n', bacterialpneumonia_train_labels[0], len(bacterialpneumonia_train_labels))
# Out:
# (2100, 150, 150, 3)
#
#  2 2100

# %%
covid_train_images.shape, normal_train_images.shape, bacterialpneumonia_train_images.shape
# Out:
# ((2100, 150, 150, 3), (2100, 150, 150, 3), (2100, 150, 150, 3))

# %% [markdown]
# # ***Load Valid Dataset :***

# %%
img= 0
img_ary= []
covid_valid_labels= []
path= Path ('C:/Dataset/Valid/Covid-19').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

covid_valid_images= np.array (img_ary) / 255.0

for i in img_ary:
  covid_valid_labels.append (0)

print(covid_valid_images.shape)
print('\n', covid_valid_labels[0], len(covid_valid_labels))
# Out:
# (450, 150, 150, 3)
#
#  0 450

# %%
img= 0
img_ary= []
normal_valid_labels= []
path= Path ('C:/Dataset/Valid/Normal').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

normal_valid_images= np.array (img_ary) / 255.0

for i in img_ary:
  normal_valid_labels.append (1)

print(normal_valid_images.shape)
print('\n', normal_valid_labels[0], len(normal_valid_labels))
# Out:
# (450, 150, 150, 3)
#
#  1 450

# %%
img= 0
img_ary= []
bacterialpneumonia_valid_labels= []
path= Path ('C:/Dataset/Valid/Bacterial Pneumonia').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

bacterialpneumonia_valid_images= np.array (img_ary) / 255.0

for i in img_ary:
  bacterialpneumonia_valid_labels.append (2)

print(bacterialpneumonia_valid_images.shape)
print('\n', bacterialpneumonia_valid_labels[0], len(bacterialpneumonia_valid_labels))
# Out:
# (450, 150, 150, 3)
#
#  2 450

# %%
covid_valid_images.shape, normal_valid_images.shape, bacterialpneumonia_valid_images.shape
# Out:
# ((450, 150, 150, 3), (450, 150, 150, 3), (450, 150, 150, 3))

# %% [markdown]
# # ***Load Test Dataset :***

# %%
img= 0
img_ary= []
covid_test_labels= []
path= Path ('C:/Dataset/Test/Covid-19').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

covid_test_images= np.array (img_ary) / 255.0

for i in img_ary:
  covid_test_labels.append (0)

print(covid_test_images.shape)
print('\n', covid_test_labels[0], len(covid_test_labels))
# Out:
# (450, 150, 150, 3)
#
#  0 450

# %%
img= 0
img_ary= []
normal_test_labels= []
path= Path ('C:/Dataset/Test/Normal').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

normal_test_images= np.array (img_ary) / 255.0

for i in img_ary:
  normal_test_labels.append (1)

print(normal_test_images.shape)
print('\n', normal_test_labels[0], len(normal_test_labels))
# Out:
# (450, 150, 150, 3)
#
#  1 450

# %%
img= 0
img_ary= []
bacterialpneumonia_test_labels= []
path= Path ('C:/Dataset/Test/Bacterial Pneumonia').expanduser()

for fname in listdir (path):
    fpath= os.path.join (path, fname)
    img= image.load_img (fpath, target_size= (150, 150),color_mode= 'rgb')
    img_ary.append (np.array (image.img_to_array (img)))

bacterialpneumonia_test_images= np.array (img_ary) / 255.0

for i in img_ary:
  bacterialpneumonia_test_labels.append (2)

print(bacterialpneumonia_test_images.shape)
print('\n', bacterialpneumonia_test_labels[0], len(bacterialpneumonia_test_labels))
# Out:
# (450, 150, 150, 3)
#
#  2 450

# %%
covid_test_images.shape, normal_test_images.shape, bacterialpneumonia_test_images.shape
# Out:
# ((450, 150, 150, 3), (450, 150, 150, 3), (450, 150, 150, 3))

# %% [markdown]
# # ***Data Visulisation :***

# %%
c_l= np.zeros(len (covid_train_images))
n_l= np.ones (len (normal_train_images))
b_l= np.full (len (bacterialpneumonia_train_images), 2, dtype= int)

X_data= np.concatenate ((covid_train_images, normal_train_images, bacterialpneumonia_train_images), axis=0)
Y_data= np.concatenate ((c_l, n_l, b_l), axis=0)

plot_images(X_data, Y_data)

# %% [markdown]
# # ***Prepare Data :***

# %%
X_train = np.concatenate ((covid_train_images, normal_train_images, bacterialpneumonia_train_images), axis=0)

Y_train = np.concatenate ((covid_train_labels, normal_train_labels, bacterialpneumonia_train_labels), axis=0)

# %%
X_valid = np.concatenate ((covid_valid_images, normal_valid_images, bacterialpneumonia_valid_images), axis=0)

Y_valid = np.concatenate ((covid_valid_labels, normal_valid_labels, bacterialpneumonia_valid_labels), axis=0)

# %%
X_test = np.concatenate ((covid_test_images, normal_test_images, bacterialpneumonia_test_images), axis=0)

Y_test = np.concatenate ((covid_test_labels, normal_test_labels, bacterialpneumonia_test_labels), axis=0)

# %% [markdown]
# # ***Categorical Lable Dataset :***

# %%
Y_train = to_categorical (
                          Y_train, num_classes = n_c
                         )

Y_valid = to_categorical (
                          Y_valid, num_classes = n_c
                         )

Y_test = to_categorical (
                         Y_test, num_classes = n_c
                        )

# %%
train_datagen = ImageDataGenerator()

valid_datagen = ImageDataGenerator()

# %% [markdown]
# # ***Detail Dataset :***

# %%
print('Number Total data : ' ,total_data)

print('\nNumber Train data : ' ,len(X_train))

print('\nNumber Valid data : ' ,len(X_valid))

print('\nNumber Test data  : ' ,len(X_test))
# Out:
# Number Total data :  9000
#
# Number Train data :  6300
#
# Number Valid data :  1350
#
# Number Test data  :  1350

# %% [markdown]
# # ***Model :***

# %%
Model_X = Xception (
                    weights = 'imagenet',
                    include_top = False, 
                    input_shape = i_s
                   ) 

out = Model_X.output

out = GlobalAveragePooling2D()(out)
out = BatchNormalization()(out)
out = Dropout(0.5)(out)

out = Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(reg))(out) 
out = BatchNormalization()(out)
out = Dropout(0.5)(out)

out = Dense(512, activation='relu', kernel_regularizer=regularizers.l2(reg))(out) 
out = BatchNormalization()(out)
out = Dropout(0.5)(out)

out = Dense(256, activation='relu', kernel_regularizer=regularizers.l2(reg))(out) 
out = BatchNormalization()(out)
out = Dropout(0.5)(out)

out = Dense(n_c, activation = 'softmax')(out)

# %%
model = Model (inputs = Model_X.input, outputs = out)

for layer in Model_X.layers:
    layer.trainable = True

model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 74, 74, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 74, 74, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 74, 74, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 72, 72, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 72, 72, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 72, 72, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 72, 72, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 72, 72, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 72, 72, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 72, 72, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 72, 72, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 36, 36, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 36, 36, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 36, 36, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 36, 36, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 36, 36, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 36, 36, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 36, 36, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 36, 36, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 36, 36, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 36, 36, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 18, 18, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 18, 18, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 18, 18, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 18, 18, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 18, 18, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 18, 18, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 18, 18, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 18, 18, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 18, 18, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 18, 18, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 9, 9, 728)    186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 9, 9, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 9, 9, 728)    2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 9, 9, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 9, 9, 728)    0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 9, 9, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 9, 9, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 9, 9, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 9, 9, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 9, 9, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 9, 9, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 9, 9, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 9, 9, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 9, 9, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 9, 9, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 9, 9, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 9, 9, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 9, 9, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 9, 9, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 9, 9, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 9, 9, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 9, 9, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 9, 9, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 9, 9, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 9, 9, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 9, 9, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 9, 9, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 9, 9, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 9, 9, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 9, 9, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 9, 9, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 9, 9, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 9, 9, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 9, 9, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 9, 9, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 9, 9, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 9, 9, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 9, 9, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 9, 9, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 9, 9, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 9, 9, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 9, 9, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 9, 9, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 9, 9, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 9, 9, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 9, 9, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 9, 9, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 9, 9, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 9, 9, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 9, 9, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 9, 9, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 9, 9, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 9, 9, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 9, 9, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 9, 9, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 9, 9, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 9, 9, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 9, 9, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 9, 9, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 9, 9, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 9, 9, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 9, 9, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 9, 9, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 9, 9, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 9, 9, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 9, 9, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 9, 9, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 9, 9, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 9, 9, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 9, 9, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 9, 9, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 9, 9, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 9, 9, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 9, 9, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 9, 9, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 9, 9, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 9, 9, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 9, 9, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 9, 9, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 9, 9, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 9, 9, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 9, 9, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 9, 9, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 9, 9, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 9, 9, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 9, 9, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 9, 9, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 9, 9, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 9, 9, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 9, 9, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 5, 5, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 5, 5, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 5, 5, 1024)   4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 5, 5, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 5, 5, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 5, 5, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 5, 5, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 5, 5, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 5, 5, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 5, 5, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 2048)         8192        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         2098176     dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 1024)         4096        dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          524800      dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 512)          2048        dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          131328      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256)          1024        dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 256)          0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 3)            771         dropout_3[0][0]
# ==================================================================================================
# Total params: 23,631,915
# Trainable params: 23,569,707
# Non-trainable params: 62,208
# __________________________________________________________________________________________________

# %% [markdown]
# # ***Set Compile Parameter :***

# %%
adam = tf.keras.optimizers.Adam (learning_rate = l_r)

model.compile (
               loss = 'categorical_crossentropy', 
               optimizer = adam, 
               metrics = ['accuracy']
              )

# %% [markdown]
# # ***Checkpoint :***

# %%
checkpoint_path = 'Checkpoints/'

checkpoint = ModelCheckpoint(
                             filepath = checkpoint_path,
                             save_freq = 'epoch',
                             save_weights_only = False,
                             verbose = 2
                            )

# %% [markdown]
# # ***fit Model :***

# %%
history= model.fit (
                    train_datagen.flow(X_train, Y_train, batch_size = b_s),
  validation_data = valid_datagen.flow(X_valid, Y_valid, batch_size = b_s),

                    validation_steps=len(X_valid) // b_s,
                    steps_per_epoch =len(X_train) // b_s,
        
                    epochs = epoch,
                    callbacks = [checkpoint]
                   )
# Out:
# Epoch 1/100
# 196/196 [==============================] - ETA: 0s - loss: 0.9420 - accuracy: 0.8382
# Epoch 00001: saving model to Checkpoints\
# WARNING:tensorflow:From C:\Users\Vahid\Anaconda3\envs\Vahid\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\Vahid\Anaconda3\envs\Vahid\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1798s 9s/step - loss: 0.9420 - accuracy: 0.8382 - val_loss: 0.6300 - val_accuracy: 0.9598
# Epoch 2/100
# 196/196 [==============================] - ETA: 0s - loss: 0.6079 - accuracy: 0.9614
# Epoch 00002: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1814s 9s/step - loss: 0.6079 - accuracy: 0.9614 - val_loss: 0.5611 - val_accuracy: 0.9784
# Epoch 3/100
# 196/196 [==============================] - ETA: 0s - loss: 0.5542 - accuracy: 0.9735
# Epoch 00003: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1824s 9s/step - loss: 0.5542 - accuracy: 0.9735 - val_loss: 0.5463 - val_accuracy: 0.9747
# Epoch 4/100
# 196/196 [==============================] - ETA: 0s - loss: 0.5414 - accuracy: 0.9802
# Epoch 00004: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1830s 9s/step - loss: 0.5414 - accuracy: 0.9802 - val_loss: 0.5258 - val_accuracy: 0.9814
# Epoch 5/100
# 196/196 [==============================] - ETA: 0s - loss: 0.5277 - accuracy: 0.9840
# Epoch 00005: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1824s 9s/step - loss: 0.5277 - accuracy: 0.9840 - val_loss: 0.5089 - val_accuracy: 0.9881
# Epoch 6/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4941 - accuracy: 0.9906
# Epoch 00006: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1827s 9s/step - loss: 0.4941 - accuracy: 0.9906 - val_loss: 0.4903 - val_accuracy: 0.9903
# Epoch 7/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4866 - accuracy: 0.9906
# Epoch 00007: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1826s 9s/step - loss: 0.4866 - accuracy: 0.9906 - val_loss: 0.5782 - val_accuracy: 0.9754
# Epoch 8/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4883 - accuracy: 0.9892
# Epoch 00008: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1829s 9s/step - loss: 0.4883 - accuracy: 0.9892 - val_loss: 0.4798 - val_accuracy: 0.9874
# Epoch 9/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4723 - accuracy: 0.9895
# Epoch 00009: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1835s 9s/step - loss: 0.4723 - accuracy: 0.9895 - val_loss: 0.5088 - val_accuracy: 0.9821
# Epoch 10/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4593 - accuracy: 0.9915
# Epoch 00010: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1835s 9s/step - loss: 0.4593 - accuracy: 0.9915 - val_loss: 0.4747 - val_accuracy: 0.9829
# Epoch 11/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4556 - accuracy: 0.9906
# Epoch 00011: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1831s 9s/step - loss: 0.4556 - accuracy: 0.9906 - val_loss: 0.4651 - val_accuracy: 0.9866
# Epoch 12/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4426 - accuracy: 0.9917
# Epoch 00012: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1834s 9s/step - loss: 0.4426 - accuracy: 0.9917 - val_loss: 0.4515 - val_accuracy: 0.9866
# Epoch 13/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4292 - accuracy: 0.9931
# Epoch 00013: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1831s 9s/step - loss: 0.4292 - accuracy: 0.9931 - val_loss: 0.4536 - val_accuracy: 0.9859
# Epoch 14/100
# 196/196 [==============================] - ETA: 0s - loss: 0.4095 - accuracy: 0.9949
# Epoch 00014: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1834s 9s/step - loss: 0.4095 - accuracy: 0.9949 - val_loss: 0.4204 - val_accuracy: 0.9903
# Epoch 15/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3824 - accuracy: 0.9984
# Epoch 00015: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1833s 9s/step - loss: 0.3824 - accuracy: 0.9984 - val_loss: 0.3974 - val_accuracy: 0.9903
# Epoch 16/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3710 - accuracy: 0.9981
# Epoch 00016: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1825s 9s/step - loss: 0.3710 - accuracy: 0.9981 - val_loss: 0.4135 - val_accuracy: 0.9874
# Epoch 17/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3672 - accuracy: 0.9959
# Epoch 00017: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1822s 9s/step - loss: 0.3672 - accuracy: 0.9959 - val_loss: 0.4717 - val_accuracy: 0.9680
# Epoch 18/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3492 - accuracy: 0.9965
# Epoch 00018: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1828s 9s/step - loss: 0.3492 - accuracy: 0.9965 - val_loss: 0.3672 - val_accuracy: 0.9851
# Epoch 19/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3303 - accuracy: 0.9974
# Epoch 00019: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1835s 9s/step - loss: 0.3303 - accuracy: 0.9974 - val_loss: 0.3634 - val_accuracy: 0.9874
# Epoch 20/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.9982
# Epoch 00020: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1815s 9s/step - loss: 0.3091 - accuracy: 0.9982 - val_loss: 0.3471 - val_accuracy: 0.9888
# Epoch 21/100
# 196/196 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.9959
# Epoch 00021: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1832s 9s/step - loss: 0.3027 - accuracy: 0.9959 - val_loss: 0.3842 - val_accuracy: 0.9829
# Epoch 22/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2904 - accuracy: 0.9938
# Epoch 00022: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1826s 9s/step - loss: 0.2904 - accuracy: 0.9938 - val_loss: 0.3675 - val_accuracy: 0.9807
# Epoch 23/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2901 - accuracy: 0.9912
# Epoch 00023: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1832s 9s/step - loss: 0.2901 - accuracy: 0.9912 - val_loss: 0.3123 - val_accuracy: 0.9836
# Epoch 24/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.9931
# Epoch 00024: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1826s 9s/step - loss: 0.2676 - accuracy: 0.9931 - val_loss: 0.2981 - val_accuracy: 0.9821
# Epoch 25/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9960
# Epoch 00025: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1830s 9s/step - loss: 0.2429 - accuracy: 0.9960 - val_loss: 0.2531 - val_accuracy: 0.9888
# Epoch 26/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2170 - accuracy: 0.9979
# Epoch 00026: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1834s 9s/step - loss: 0.2170 - accuracy: 0.9979 - val_loss: 0.2857 - val_accuracy: 0.9807
# Epoch 27/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1946 - accuracy: 0.9998
# Epoch 00027: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1840s 9s/step - loss: 0.1946 - accuracy: 0.9998 - val_loss: 0.2692 - val_accuracy: 0.9859
# Epoch 28/100
# 196/196 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.9866
# Epoch 00028: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1830s 9s/step - loss: 0.2336 - accuracy: 0.9866 - val_loss: 0.2212 - val_accuracy: 0.9859
# Epoch 29/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1900 - accuracy: 0.9935
# Epoch 00029: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1819s 9s/step - loss: 0.1900 - accuracy: 0.9935 - val_loss: 0.2127 - val_accuracy: 0.9821
# Epoch 30/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1732 - accuracy: 0.9960
# Epoch 00030: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1832s 9s/step - loss: 0.1732 - accuracy: 0.9960 - val_loss: 0.1935 - val_accuracy: 0.9859
# Epoch 31/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1438 - accuracy: 0.9997
# Epoch 00031: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1829s 9s/step - loss: 0.1438 - accuracy: 0.9997 - val_loss: 0.1655 - val_accuracy: 0.9918
# Epoch 32/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1259 - accuracy: 1.0000
# Epoch 00032: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1836s 9s/step - loss: 0.1259 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9918
# Epoch 33/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1249 - accuracy: 0.9979
# Epoch 00033: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1820s 9s/step - loss: 0.1249 - accuracy: 0.9979 - val_loss: 0.2277 - val_accuracy: 0.9792
# Epoch 34/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1308 - accuracy: 0.9939
# Epoch 00034: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1823s 9s/step - loss: 0.1308 - accuracy: 0.9939 - val_loss: 0.2541 - val_accuracy: 0.9740
# Epoch 35/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9941
# Epoch 00035: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1832s 9s/step - loss: 0.1220 - accuracy: 0.9941 - val_loss: 0.1654 - val_accuracy: 0.9851
# Epoch 36/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9957
# Epoch 00036: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1831s 9s/step - loss: 0.1071 - accuracy: 0.9957 - val_loss: 0.1518 - val_accuracy: 0.9814
# Epoch 37/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9946
# Epoch 00037: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1830s 9s/step - loss: 0.1024 - accuracy: 0.9946 - val_loss: 0.1496 - val_accuracy: 0.9821
# Epoch 38/100
# 196/196 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9938
# Epoch 00038: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1830s 9s/step - loss: 0.1044 - accuracy: 0.9938 - val_loss: 0.1222 - val_accuracy: 0.9874
# Epoch 39/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9990
# Epoch 00039: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1836s 9s/step - loss: 0.0736 - accuracy: 0.9990 - val_loss: 0.0975 - val_accuracy: 0.9918
# Epoch 40/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 1.0000
# Epoch 00040: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1832s 9s/step - loss: 0.0605 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9911
# Epoch 41/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 1.0000
# Epoch 00041: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1834s 9s/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9903
# Epoch 42/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 1.0000
# Epoch 00042: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1828s 9s/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 0.9903
# Epoch 43/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 1.0000
# Epoch 00043: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1833s 9s/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 0.9903
# Epoch 44/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9984
# Epoch 00044: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1837s 9s/step - loss: 0.0455 - accuracy: 0.9984 - val_loss: 0.6989 - val_accuracy: 0.8222
# Epoch 45/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9898
# Epoch 00045: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1844s 9s/step - loss: 0.0909 - accuracy: 0.9898 - val_loss: 0.1108 - val_accuracy: 0.9829
# Epoch 46/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9957
# Epoch 00046: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1850s 9s/step - loss: 0.0655 - accuracy: 0.9957 - val_loss: 0.1441 - val_accuracy: 0.9747
# Epoch 47/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9971
# Epoch 00047: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1843s 9s/step - loss: 0.0561 - accuracy: 0.9971 - val_loss: 0.1023 - val_accuracy: 0.9866
# Epoch 48/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9974
# Epoch 00048: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1854s 9s/step - loss: 0.0489 - accuracy: 0.9974 - val_loss: 0.1579 - val_accuracy: 0.9658
# Epoch 49/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9974
# Epoch 00049: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1847s 9s/step - loss: 0.0494 - accuracy: 0.9974 - val_loss: 0.0780 - val_accuracy: 0.9911
# Epoch 50/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9949
# Epoch 00050: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1845s 9s/step - loss: 0.0567 - accuracy: 0.9949 - val_loss: 0.0941 - val_accuracy: 0.9836
# Epoch 51/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9974
# Epoch 00051: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1846s 9s/step - loss: 0.0471 - accuracy: 0.9974 - val_loss: 0.1017 - val_accuracy: 0.9821
# Epoch 52/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9994
# Epoch 00052: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1831s 9s/step - loss: 0.0363 - accuracy: 0.9994 - val_loss: 0.0938 - val_accuracy: 0.9829
# Epoch 53/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9962
# Epoch 00053: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1833s 9s/step - loss: 0.0478 - accuracy: 0.9962 - val_loss: 0.1183 - val_accuracy: 0.9844
# Epoch 54/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9986
# Epoch 00054: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1838s 9s/step - loss: 0.0347 - accuracy: 0.9986 - val_loss: 0.0810 - val_accuracy: 0.9881
# Epoch 55/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 1.0000
# Epoch 00055: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1839s 9s/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.0804 - val_accuracy: 0.9896
# Epoch 56/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9968
# Epoch 00056: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1849s 9s/step - loss: 0.0395 - accuracy: 0.9968 - val_loss: 0.0689 - val_accuracy: 0.9903
# Epoch 57/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9973
# Epoch 00057: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1829s 9s/step - loss: 0.0366 - accuracy: 0.9973 - val_loss: 0.0636 - val_accuracy: 0.9903
# Epoch 58/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0396 - accuracy: 0.9966
# Epoch 00058: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1828s 9s/step - loss: 0.0396 - accuracy: 0.9966 - val_loss: 0.1088 - val_accuracy: 0.9814
# Epoch 59/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9974
# Epoch 00059: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1840s 9s/step - loss: 0.0367 - accuracy: 0.9974 - val_loss: 0.0891 - val_accuracy: 0.9874
# Epoch 60/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9954
# Epoch 00060: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1832s 9s/step - loss: 0.0444 - accuracy: 0.9954 - val_loss: 0.1699 - val_accuracy: 0.9650
# Epoch 61/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9931
# Epoch 00061: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1828s 9s/step - loss: 0.0659 - accuracy: 0.9931 - val_loss: 0.0777 - val_accuracy: 0.9888
# Epoch 62/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9994
# Epoch 00062: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1835s 9s/step - loss: 0.0337 - accuracy: 0.9994 - val_loss: 0.1016 - val_accuracy: 0.9836
# Epoch 63/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0302 - accuracy: 0.9989
# Epoch 00063: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1829s 9s/step - loss: 0.0302 - accuracy: 0.9989 - val_loss: 0.1472 - val_accuracy: 0.9799
# Epoch 64/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9955
# Epoch 00064: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1842s 9s/step - loss: 0.0455 - accuracy: 0.9955 - val_loss: 1.0928 - val_accuracy: 0.6205
# Epoch 65/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9984
# Epoch 00065: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1832s 9s/step - loss: 0.0366 - accuracy: 0.9984 - val_loss: 0.0734 - val_accuracy: 0.9903
# Epoch 66/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9995
# Epoch 00066: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1835s 9s/step - loss: 0.0289 - accuracy: 0.9995 - val_loss: 0.0670 - val_accuracy: 0.9903
# Epoch 67/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9973
# Epoch 00067: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1840s 9s/step - loss: 0.0347 - accuracy: 0.9973 - val_loss: 0.1471 - val_accuracy: 0.9777
# Epoch 68/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9974
# Epoch 00068: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1828s 9s/step - loss: 0.0434 - accuracy: 0.9974 - val_loss: 0.0934 - val_accuracy: 0.9881
# Epoch 69/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9998
# Epoch 00069: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1846s 9s/step - loss: 0.0278 - accuracy: 0.9998 - val_loss: 0.0906 - val_accuracy: 0.9844
# Epoch 70/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 1.0000
# Epoch 00070: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1837s 9s/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.0803 - val_accuracy: 0.9851
# Epoch 71/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9968
# Epoch 00071: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1838s 9s/step - loss: 0.0378 - accuracy: 0.9968 - val_loss: 0.1133 - val_accuracy: 0.9844
# Epoch 72/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9960
# Epoch 00072: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1844s 9s/step - loss: 0.0474 - accuracy: 0.9960 - val_loss: 0.4789 - val_accuracy: 0.8542
# Epoch 73/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9976
# Epoch 00073: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1848s 9s/step - loss: 0.0426 - accuracy: 0.9976 - val_loss: 0.1200 - val_accuracy: 0.9732
# Epoch 74/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9982
# Epoch 00074: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1849s 9s/step - loss: 0.0319 - accuracy: 0.9982 - val_loss: 0.0954 - val_accuracy: 0.9807
# Epoch 75/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9998
# Epoch 00075: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1852s 9s/step - loss: 0.0249 - accuracy: 0.9998 - val_loss: 0.0784 - val_accuracy: 0.9888
# Epoch 76/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 1.0000
# Epoch 00076: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1836s 9s/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0783 - val_accuracy: 0.9888
# Epoch 77/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9994
# Epoch 00077: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1844s 9s/step - loss: 0.0187 - accuracy: 0.9994 - val_loss: 0.9557 - val_accuracy: 0.8222
# Epoch 78/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9982
# Epoch 00078: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1848s 9s/step - loss: 0.0348 - accuracy: 0.9982 - val_loss: 0.1812 - val_accuracy: 0.9754
# Epoch 79/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9957
# Epoch 00079: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1845s 9s/step - loss: 0.0524 - accuracy: 0.9957 - val_loss: 0.0953 - val_accuracy: 0.9866
# Epoch 80/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9997
# Epoch 00080: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1851s 9s/step - loss: 0.0288 - accuracy: 0.9997 - val_loss: 0.0672 - val_accuracy: 0.9933
# Epoch 81/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9982
# Epoch 00081: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1849s 9s/step - loss: 0.0295 - accuracy: 0.9982 - val_loss: 0.0695 - val_accuracy: 0.9888
# Epoch 82/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 1.0000
# Epoch 00082: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1841s 9s/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 0.9896
# Epoch 83/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 1.0000
# Epoch 00083: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1845s 9s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9903
# Epoch 84/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9998
# Epoch 00084: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1850s 9s/step - loss: 0.0114 - accuracy: 0.9998 - val_loss: 0.0643 - val_accuracy: 0.9896
# Epoch 85/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0340 - accuracy: 0.9986
# Epoch 00085: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1865s 10s/step - loss: 0.0340 - accuracy: 0.9986 - val_loss: 0.3541 - val_accuracy: 0.9449
# Epoch 86/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9907
# Epoch 00086: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1842s 9s/step - loss: 0.0701 - accuracy: 0.9907 - val_loss: 0.0672 - val_accuracy: 0.9881
# Epoch 87/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9982
# Epoch 00087: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1848s 9s/step - loss: 0.0388 - accuracy: 0.9982 - val_loss: 0.0911 - val_accuracy: 0.9874
# Epoch 88/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9992
# Epoch 00088: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1842s 9s/step - loss: 0.0285 - accuracy: 0.9992 - val_loss: 0.1471 - val_accuracy: 0.9769
# Epoch 89/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9971
# Epoch 00089: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1844s 9s/step - loss: 0.0338 - accuracy: 0.9971 - val_loss: 0.0688 - val_accuracy: 0.9874
# Epoch 90/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9984
# Epoch 00090: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1848s 9s/step - loss: 0.0300 - accuracy: 0.9984 - val_loss: 0.0970 - val_accuracy: 0.9874
# Epoch 91/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9990
# Epoch 00091: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1840s 9s/step - loss: 0.0268 - accuracy: 0.9990 - val_loss: 0.0918 - val_accuracy: 0.9859
# Epoch 92/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9986
# Epoch 00092: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1845s 9s/step - loss: 0.0305 - accuracy: 0.9986 - val_loss: 0.1283 - val_accuracy: 0.9762
# Epoch 93/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.9992
# Epoch 00093: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1834s 9s/step - loss: 0.0244 - accuracy: 0.9992 - val_loss: 0.0964 - val_accuracy: 0.9859
# Epoch 94/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9954
# Epoch 00094: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1841s 9s/step - loss: 0.0466 - accuracy: 0.9954 - val_loss: 0.0777 - val_accuracy: 0.9851
# Epoch 95/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9994
# Epoch 00095: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1834s 9s/step - loss: 0.0280 - accuracy: 0.9994 - val_loss: 0.0727 - val_accuracy: 0.9888
# Epoch 96/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 1.0000
# Epoch 00096: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1851s 9s/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.0841 - val_accuracy: 0.9888
# Epoch 97/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9986
# Epoch 00097: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1846s 9s/step - loss: 0.0270 - accuracy: 0.9986 - val_loss: 0.0985 - val_accuracy: 0.9836
# Epoch 98/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9990
# Epoch 00098: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1836s 9s/step - loss: 0.0236 - accuracy: 0.9990 - val_loss: 0.2976 - val_accuracy: 0.9219
# Epoch 99/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9970
# Epoch 00099: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1833s 9s/step - loss: 0.0394 - accuracy: 0.9970 - val_loss: 0.1291 - val_accuracy: 0.9807
# Epoch 100/100
# 196/196 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9978
# Epoch 00100: saving model to Checkpoints\
# INFO:tensorflow:Assets written to: Checkpoints\assets
# 196/196 [==============================] - 1836s 9s/step - loss: 0.0359 - accuracy: 0.9978 - val_loss: 0.0809 - val_accuracy: 0.9896

# %% [markdown]
# # ***Save Model :***

# %%
model.save('Model.h5')

# %% [markdown]
# # ***Evaluate Model :***

# %%
train_score = model.evaluate(X_train, Y_train, verbose=0)
valid_score = model.evaluate(X_valid, Y_valid, verbose=0)
test_score  = model.evaluate(X_test , Y_test , verbose=0)

print(f'Train loss: {train_score[0]} \n Train accuracy: {train_score[1]}')
print(f'Valid loss: {valid_score[0]} \n Valid accuracy: {valid_score[1]}')
print(f'Test  loss: {test_score[0]}  \n Test accuracy : {test_score[1]}')
# Out:
# Train loss: 0.0342976450920105
#  Train accuracy: 0.9998412728309631
# Valid loss: 0.08067579567432404
#  Valid accuracy: 0.9896296262741089
# Test  loss: 0.06437096744775772
#  Test accuracy : 0.9925925731658936

# %% [markdown]
# # ***Results Evaluate Model :***

# %%
Y_pred = model.predict(X_test)

Y_pred = np.argmax (Y_pred, axis=1)
Y_true = np.argmax (Y_test, axis=1)

# %%
target = ['Covid-19', 'Normal', 'BacterialPneumonia']
print(classification_report(Y_true, Y_pred, target_names = target))
# Out:
#                     precision    recall  f1-score   support
#
#           Covid-19       1.00      1.00      1.00       450
#             Normal       0.98      1.00      0.99       450
# BacterialPneumonia       0.99      0.98      0.99       450
#
#           accuracy                           0.99      1350
#          macro avg       0.99      0.99      0.99      1350
#       weighted avg       0.99      0.99      0.99      1350

# %% [markdown]
# # ***Confusion Matrix :***

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
        
    plt.tight_layout()
    plt.ylabel('True label', fontstyle = 'italic', color='blue', fontsize = 'x-large')
    plt.xlabel('Predicted label', fontstyle = 'italic', color='blue', fontsize = 'xx-large')

cnf_matrix = confusion_matrix(Y_true, Y_pred)
np.set_printoptions(precision=2)

fig = plt.figure(figsize=(8,8))
fig.patch.set_facecolor('gray')
plot_confusion_matrix(cnf_matrix, classes = target, title='Confusion matrix, without normalization\n\n')

fig = plt.figure(figsize=(8,8))
fig.patch.set_facecolor('gray')
plot_confusion_matrix(cnf_matrix, classes = target, normalize = True, title = 'Normalized confusion matrix\n\n')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[449   0   1]
#  [  0 448   2]
#  [  0   7 443]]
# Normalized confusion matrix
# [[1.   0.   0.  ]
#  [0.   1.   0.  ]
#  [0.   0.02 0.98]]

# %% [markdown]
# # ***Plot Accuracy :***

# %%
plt.figure(figsize=(17,10))
plt.style.use('dark_background')

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])

plt.show()

# %% [markdown]
# # ***Plot Loss :***

# %%
plt.figure(figsize=(17,10))
plt.style.use('dark_background')

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])

plt.show()
